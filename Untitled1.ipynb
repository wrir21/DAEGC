# %% [markdown]
# <a href="https://colab.research.google.com/github/wrir21/DAEGC/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content
# Out:
# /content

# %%
rm -r DAEGC
# Out:
# rm: cannot remove 'DAEGC': No such file or directory

# %%
# %%bash
# git clone https://github.com/wrir21/DAEGC.git
# Out:
# Cloning into 'DAEGC'...

# %%
cd /content/DAEGC
# Out:
# /content/DAEGC

# %%
mkdir pretrain

# %% [markdown]
# ### 环境配置

# %%
# %%bash
# pip3 install munkres
# pip3 install -U scikit-learn
# pip install torch-geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 37.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# **在pretrain里更改loss，在daegc里更改更新P的条件**

# %% [markdown]
# # **Cora** 目标
#
# *   预训练：acc 0.747 nmi 0.576 ari 0.525
# *   训练：acc 0.771 nmi 0.611 ari 0.574

# %% [markdown]
# ## **优化1**
# *   （daegc）loss = 10 * kl_loss + re_loss
# *  （pretrain）loss = loss + args.p * torch.norm(abs(A1_pred - A2_pred))
#
# ---
# 将torch.sum 改为了torch.norm

# %% [markdown]
# ### **第一次**

# %% [markdown]
# #### pretrain：acc 0.7330, nmi 0.5559, ari 0.5005, f1 0.6883

# %%
# !python3 pretrain3.py --name Cora --max_epoch 500
# Out:
# use cuda: True
# Namespace(name='Cora', max_epoch=500, lr=0.02, n_clusters=7, hidden_size=64, embedding_size=12, weight_decay=0.005, alpha=0.2, cuda=True, k=None, p=0.02, input_dim=1433)
# GAT(
#   (conv1): GATLayer (1433 -> 64)
#   (conv2): GATLayer (64 -> 12)
# )
# epoch 0:acc 0.5583, nmi 0.3541, ari 0.2799, f1 0.5106
# epoch 1:acc 0.4886, nmi 0.3553, ari 0.2774, f1 0.4281
# epoch 2:acc 0.5705, nmi 0.3752, ari 0.3006, f1 0.5114
# epoch 3:acc 0.5727, nmi 0.3754, ari 0.3015, f1 0.5146
# epoch 4:acc 0.5694, nmi 0.3814, ari 0.3025, f1 0.5127
# epoch 5:acc 0.5679, nmi 0.3791, ari 0.2998, f1 0.5102
# epoch 6:acc 0.5325, nmi 0.3866, ari 0.2909, f1 0.4763
# epoch 7:acc 0.5229, nmi 0.3887, ari 0.2876, f1 0.4685
# epoch 8:acc 0.5273, nmi 0.3974, ari 0.2962, f1 0.4717
# epoch 9:acc 0.5314, nmi 0.4066, ari 0.3085, f1 0.4745
# epoch 10:acc 0.5336, nmi 0.4076, ari 0.3093, f1 0.4772
# epoch 11:acc 0.5318, nmi 0.4090, ari 0.3073, f1 0.4768
# epoch 12:acc 0.5399, nmi 0.4090, ari 0.3065, f1 0.4864
# ...

# %% [markdown]
# #### daegc：epoch 448:acc 0.6414, nmi 0.4813, ari 0.4192, f1 0.5442

# %%
# !python3 daegc3.py --name Cora --epoch 140 --max_epoch 500
# Out:
# use cuda: True
# Namespace(name='Cora', epoch=140, max_epoch=500, lr=0.05, n_clusters=7, update_interval=1, hidden_size=64, embedding_size=12, weight_decay=0.005, alpha=0.2, cuda=True, k=None, pretrain_path='./pretrain/predaegc_Cora_140.pkl', input_dim=1433)
# DAEGC(
#   (gat): GAT(
#     (conv1): GATLayer (1433 -> 64)
#     (conv2): GATLayer (64 -> 12)
#   )
# )
# epoch pretrain:acc 0.7315, nmi 0.5535, ari 0.4976, f1 0.6868
# epoch 0:acc 0.7315, nmi 0.5535, ari 0.4976, f1 0.6868
# epoch 1:acc 0.5580, nmi 0.3976, ari 0.2681, f1 0.4724
# epoch 2:acc 0.4479, nmi 0.2629, ari 0.1168, f1 0.2698
# epoch 3:acc 0.3456, nmi 0.0990, ari 0.0259, f1 0.1452
# epoch 4:acc 0.3165, nmi 0.1563, ari 0.0915, f1 0.1621
# epoch 5:acc 0.5203, nmi 0.3955, ari 0.3511, f1 0.3059
# epoch 6:acc 0.3445, nmi 0.1035, ari 0.0308, f1 0.1586
# epoch 7:acc 0.4092, nmi 0.3185, ari 0.2185, f1 0.1620
# epoch 8:acc 0.4343, nmi 0.3205, ari 0.2082, f1 0.2335
# epoch 9:acc 0.3527, nmi 0.2103, ari 0.1014, f1 0.1803
# ...

# %% [markdown]
# ## **优化2**
#
# *   （daegc）loss = 100 * kl_loss + re_loss
# *  （pretrain）loss = loss + args.p * torch.norm(abs(A1_pred - A2_pred))
# ---
# 将daegc里面的loss里面的10改为100

# %% [markdown]
# ### 第1次

# %% [markdown]
# #### pretrain：epoch 98:acc 0.7123, nmi 0.5211, ari 0.4643, f1 0.6713

# %%
# !python3 pretrain3.py --name Cora --max_epoch 500
# Out:
# use cuda: True
# Namespace(name='Cora', max_epoch=500, lr=0.02, n_clusters=7, hidden_size=64, embedding_size=12, weight_decay=0.005, alpha=0.2, cuda=True, k=None, p=0.02, input_dim=1433)
# GAT(
#   (conv1): GATLayer (1433 -> 64)
#   (conv2): GATLayer (64 -> 12)
# )
# epoch 0:acc 0.4346, nmi 0.3102, ari 0.2019, f1 0.4014
# epoch 1:acc 0.5063, nmi 0.3333, ari 0.2325, f1 0.4668
# epoch 2:acc 0.5155, nmi 0.3464, ari 0.2462, f1 0.4739
# epoch 3:acc 0.5140, nmi 0.3456, ari 0.2445, f1 0.4720
# epoch 4:acc 0.5240, nmi 0.3130, ari 0.2291, f1 0.4642
# epoch 5:acc 0.5332, nmi 0.3096, ari 0.2457, f1 0.4699
# epoch 6:acc 0.5262, nmi 0.3076, ari 0.2426, f1 0.4720
# epoch 7:acc 0.5126, nmi 0.2890, ari 0.2252, f1 0.4602
# epoch 8:acc 0.5055, nmi 0.2819, ari 0.2179, f1 0.4555
# epoch 9:acc 0.4745, nmi 0.2591, ari 0.1813, f1 0.4309
# epoch 10:acc 0.4668, nmi 0.2560, ari 0.1764, f1 0.4254
# epoch 11:acc 0.4719, nmi 0.2583, ari 0.1841, f1 0.4288
# epoch 12:acc 0.4380, nmi 0.2799, ari 0.1957, f1 0.3869
# ...

# %% [markdown]
# #### daegc：epoch 457:acc 0.6924, nmi 0.5082, ari 0.4518, f1 0.6148

# %%
# !python3 daegc3.py --name Cora --epoch 98 --max_epoch 500
# Out:
# use cuda: True
# Namespace(name='Cora', epoch=98, max_epoch=500, lr=0.05, n_clusters=7, update_interval=1, hidden_size=64, embedding_size=12, weight_decay=0.005, alpha=0.2, cuda=True, k=None, pretrain_path='./pretrain/predaegc_Cora_98.pkl', input_dim=1433)
# DAEGC(
#   (gat): GAT(
#     (conv1): GATLayer (1433 -> 64)
#     (conv2): GATLayer (64 -> 12)
#   )
# )
# epoch pretrain:acc 0.7120, nmi 0.5212, ari 0.4642, f1 0.6709
# epoch 0:acc 0.7120, nmi 0.5212, ari 0.4642, f1 0.6709
# epoch 1:acc 0.4767, nmi 0.4013, ari 0.2929, f1 0.3997
# epoch 2:acc 0.3634, nmi 0.1708, ari 0.0527, f1 0.1923
# epoch 3:acc 0.3327, nmi 0.0592, ari 0.0096, f1 0.1175
# epoch 4:acc 0.3955, nmi 0.2773, ari 0.1622, f1 0.1911
# epoch 5:acc 0.3748, nmi 0.2971, ari 0.1909, f1 0.2064
# epoch 6:acc 0.3955, nmi 0.3144, ari 0.2042, f1 0.2452
# epoch 7:acc 0.3061, nmi 0.1737, ari 0.0740, f1 0.1482
# epoch 8:acc 0.3984, nmi 0.2090, ari 0.1382, f1 0.2444
# epoch 9:acc 0.4583, nmi 0.3012, ari 0.2466, f1 0.2540
# ...

# %% [markdown]
# ###第2次

# %% [markdown]
# #### pretrain：epoch 210:acc 0.7304, nmi 0.5412, ari 0.5019, f1 0.6833

# %%
# !python3 pretrain3.py --name Cora --max_epoch 500
# Out:
# use cuda: True
# Namespace(name='Cora', max_epoch=500, lr=0.02, n_clusters=7, hidden_size=64, embedding_size=12, weight_decay=0.005, alpha=0.2, cuda=True, k=None, p=0.02, input_dim=1433)
# GAT(
#   (conv1): GATLayer (1433 -> 64)
#   (conv2): GATLayer (64 -> 12)
# )
# epoch 0:acc 0.3977, nmi 0.2728, ari 0.1688, f1 0.3536
# epoch 1:acc 0.5041, nmi 0.3500, ari 0.2614, f1 0.4319
# epoch 2:acc 0.4900, nmi 0.3747, ari 0.2670, f1 0.5086
# epoch 3:acc 0.4867, nmi 0.3583, ari 0.2508, f1 0.5046
# epoch 4:acc 0.5044, nmi 0.3280, ari 0.2387, f1 0.4602
# epoch 5:acc 0.5096, nmi 0.3253, ari 0.2324, f1 0.4649
# epoch 6:acc 0.5129, nmi 0.3262, ari 0.2328, f1 0.4678
# epoch 7:acc 0.5185, nmi 0.3317, ari 0.2211, f1 0.4693
# epoch 8:acc 0.5188, nmi 0.3284, ari 0.2189, f1 0.4682
# epoch 9:acc 0.5166, nmi 0.3287, ari 0.2158, f1 0.4651
# epoch 10:acc 0.5273, nmi 0.3376, ari 0.2245, f1 0.4739
# epoch 11:acc 0.5244, nmi 0.3381, ari 0.2271, f1 0.4698
# epoch 12:acc 0.5273, nmi 0.3411, ari 0.2307, f1 0.4723
# ...

# %% [markdown]
# #### daegc：epoch 498:acc 0.6939, nmi 0.5047, ari 0.4460, f1 0.6160

# %%
# !python3 daegc3.py --name Cora --epoch 210 --max_epoch 500
# Out:
# use cuda: True
# Namespace(name='Cora', epoch=210, max_epoch=500, lr=0.05, n_clusters=7, update_interval=1, hidden_size=64, embedding_size=12, weight_decay=0.005, alpha=0.2, cuda=True, k=None, pretrain_path='./pretrain/predaegc_Cora_210.pkl', input_dim=1433)
# DAEGC(
#   (gat): GAT(
#     (conv1): GATLayer (1433 -> 64)
#     (conv2): GATLayer (64 -> 12)
#   )
# )
# epoch pretrain:acc 0.7323, nmi 0.5436, ari 0.5045, f1 0.6855
# epoch 0:acc 0.7323, nmi 0.5436, ari 0.5045, f1 0.6855
# epoch 1:acc 0.3951, nmi 0.2976, ari 0.1910, f1 0.2112
# epoch 2:acc 0.5270, nmi 0.3325, ari 0.2731, f1 0.4073
# epoch 3:acc 0.3999, nmi 0.2883, ari 0.2005, f1 0.2427
# epoch 4:acc 0.3763, nmi 0.1776, ari 0.0558, f1 0.1779
# epoch 5:acc 0.3623, nmi 0.2494, ari 0.0391, f1 0.2328
# epoch 6:acc 0.4749, nmi 0.4105, ari 0.2906, f1 0.3193
# epoch 7:acc 0.3516, nmi 0.2726, ari 0.1528, f1 0.2280
# epoch 8:acc 0.4417, nmi 0.2821, ari 0.1833, f1 0.2609
# epoch 9:acc 0.5044, nmi 0.3573, ari 0.2591, f1 0.3242
# ...

# %% [markdown]
# 方案：loss = loss + args.p * torch.norm(abs(A1_pred - A2_pred))

# %% [markdown]
# ### 第3次
# epoch 134:acc 0.7194, nmi 0.5364, ari 0.4748, f1 0.6781

# %%
# !python3 pretrain3.py --name Cora --max_epoch 500
# Out:
# use cuda: True
# Namespace(name='Cora', max_epoch=500, lr=0.02, n_clusters=7, hidden_size=64, embedding_size=12, weight_decay=0.005, alpha=0.2, cuda=True, k=None, p=0.02, input_dim=1433)
# GAT(
#   (conv1): GATLayer (1433 -> 64)
#   (conv2): GATLayer (64 -> 12)
# )
# epoch 0:acc 0
# epoch 5:acc 0.5654, nmi 0.4123, ari 0.3134, f1 0.5365
# epoch 6:acc 0.5650, nmi 0.4101, ari 0.3109, f1 0.5379
# epoch 7:acc 0.6388, nmi 0.4170, ari 0.3607, f1 0.6258
# epoch 8:acc 0.6366, nmi 0.4131, ari 0.3565, f1 0.6237
# epoch 9:acc 0.6381, nmi 0.4154, ari 0.3579, f1 0.6254
# epoch 10:acc 0.6366, nmi 0.4121, ari 0.3552, f1 0.6253
# epoch 11:acc 0.6414, nmi 0.4133, ari 0.3594, f1 0.6296
# epoch 12:acc 0.6448, nmi 0.4193, ari 0.3641, f1 0.6345
# ...

# %% [markdown]
# #### daegc：epoch 225:acc 0.7145, nmi 0.5172, ari 0.4925, f1 0.6618

# %%
# !python3 daegc3.py --name Cora --epoch 148 --max_epoch 500
# Out:
# use cuda: True
# Namespace(name='Cora', epoch=148, max_epoch=500, lr=0.05, n_clusters=7, update_interval=1, hidden_size=64, embedding_size=12, weight_decay=0.005, alpha=0.2, cuda=True, k=None, pretrain_path='./pretrain/predaegc_Cora_148.pkl', input_dim=1433)
# DAEGC(
#   (gat): GAT(
#     (conv1): GATLayer (1433 -> 64)
#     (conv2): GATLayer (64 -> 12)
#   )
# )
# epoch pretrain:acc 0.7319, nmi 0.5469, ari 0.5047, f1 0.6845
# epoch 0:acc 0.7319, nmi 0.5469, ari 0.5047, f1 0.6845
# epoch 1:acc 0.6924, nmi 0.4750, ari 0.4939, f1 0.6198
# epoch 2:acc 0.3275, nmi 0.0567, ari 0.0028, f1 0.1294
# epoch 3:acc 0.3035, nmi 0.0069, ari -0.0001, f1 0.0704
# epoch 4:acc 0.3172, nmi 0.2041, ari 0.0563, f1 0.1909
# epoch 5:acc 0.4919, nmi 0.3930, ari 0.2806, f1 0.2754
# epoch 6:acc 0.4103, nmi 0.2991, ari 0.1278, f1 0.2385
# epoch 7:acc 0.4605, nmi 0.3275, ari 0.2434, f1 0.3080
# epoch 8:acc 0.4273, nmi 0.3352, ari 0.1881, f1 0.2393
# epoch 9:acc 0.2932, nmi 0.1505, ari 0.0680, f1 0.1192
# ...

# %%
# !python3 daegc3.py --name Cora --epoch 148 --max_epoch 500
# Out:
# use cuda: True
# Namespace(name='Cora', epoch=148, max_epoch=500, lr=0.05, n_clusters=7, update_interval=1, hidden_size=64, embedding_size=12, weight_decay=0.005, alpha=0.2, cuda=True, k=None, pretrain_path='./pretrain/predaegc_Cora_148.pkl', input_dim=1433)
# DAEGC(
#   (gat): GAT(
#     (conv1): GATLayer (1433 -> 64)
#     (conv2): GATLayer (64 -> 12)
#   )
# )
# epoch pretrain:acc 0.7315, nmi 0.5461, ari 0.5040, f1 0.6841
# epoch 0:acc 0.7315, nmi 0.5461, ari 0.5040, f1 0.6841
# epoch 1:acc 0.6924, nmi 0.4752, ari 0.4939, f1 0.6198
# epoch 2:acc 0.3275, nmi 0.0567, ari 0.0028, f1 0.1294
# epoch 3:acc 0.3035, nmi 0.0069, ari -0.0001, f1 0.0704
# epoch 4:acc 0.3209, nmi 0.2063, ari 0.0561, f1 0.1934
# epoch 5:acc 0.4963, nmi 0.4006, ari 0.2924, f1 0.2771
# epoch 6:acc 0.4095, nmi 0.2995, ari 0.1274, f1 0.2380
# epoch 7:acc 0.4634, nmi 0.3348, ari 0.2532, f1 0.3104
# epoch 8:acc 0.4269, nmi 0.3345, ari 0.1871, f1 0.2396
# epoch 9:acc 0.2954, nmi 0.1529, ari 0.0705, f1 0.1196
# ...

# %% [markdown]
# ### 第11次

# %% [markdown]
# #### pretrain
# epoch 266:acc 0.6928, nmi 0.4910, ari 0.4678, f1 0.6396

# %%
# !python3 pretrain3.py --name Cora --max_epoch 500
# Out:
# use cuda: True
# Namespace(name='Cora', max_epoch=500, lr=0.02, n_clusters=7, hidden_size=64, embedding_size=12, weight_decay=0.005, alpha=0.2, cuda=True, k=None, p=0.02, input_dim=1433)
# GAT(
#   (conv1): GATLayer (1433 -> 64)
#   (conv2): GATLayer (64 -> 12)
# )
# epoch 0:acc 0.5417, nmi 0.3385, ari 0.2531, f1 0.4842
# epoch 1:acc 0.5292, nmi 0.3355, ari 0.2486, f1 0.4156
# epoch 2:acc 0.5606, nmi 0.3789, ari 0.2711, f1 0.5074
# epoch 3:acc 0.5775, nmi 0.3991, ari 0.2986, f1 0.5605
# epoch 4:acc 0.5303, nmi 0.3753, ari 0.2783, f1 0.5432
# epoch 5:acc 0.5170, nmi 0.3773, ari 0.2815, f1 0.5322
# epoch 6:acc 0.5318, nmi 0.3677, ari 0.2831, f1 0.4918
# epoch 7:acc 0.5225, nmi 0.3715, ari 0.2848, f1 0.4856
# epoch 8:acc 0.5181, nmi 0.3702, ari 0.2837, f1 0.4874
# epoch 9:acc 0.5240, nmi 0.3687, ari 0.2855, f1 0.4781
# epoch 10:acc 0.5181, nmi 0.3659, ari 0.2793, f1 0.4694
# epoch 11:acc 0.5222, nmi 0.3720, ari 0.2860, f1 0.4672
# epoch 12:acc 0.5222, nmi 0.3759, ari 0.2874, f1 0.4924
# ...

# %%
# !python3 pretrain3.py --name Cora --max_epoch 500
# Out:
# use cuda: True
# Namespace(name='Cora', max_epoch=500, lr=0.02, n_clusters=7, hidden_size=64, embedding_size=12, weight_decay=0.005, alpha=0.2, cuda=True, k=None, p=0.02, input_dim=1433)
# GAT(
#   (conv1): GATLayer (1433 -> 64)
#   (conv2): GATLayer (64 -> 12)
# )
# epoch 0:acc 0.5015, nmi 0.3333, ari 0.2573, f1 0.4505
# epoch 1:acc 0.5007, nmi 0.3556, ari 0.2654, f1 0.4514
# epoch 2:acc 0.5288, nmi 0.3835, ari 0.3129, f1 0.4725
# epoch 3:acc 0.4989, nmi 0.3730, ari 0.2869, f1 0.4791
# epoch 4:acc 0.5510, nmi 0.3694, ari 0.2940, f1 0.5408
# epoch 5:acc 0.5543, nmi 0.3676, ari 0.2974, f1 0.5423
# epoch 6:acc 0.5923, nmi 0.3896, ari 0.3489, f1 0.5685
# epoch 7:acc 0.5650, nmi 0.3935, ari 0.3264, f1 0.5188
# epoch 8:acc 0.5838, nmi 0.4051, ari 0.3426, f1 0.5279
# epoch 9:acc 0.5842, nmi 0.4078, ari 0.3452, f1 0.5284
# epoch 10:acc 0.5879, nmi 0.4119, ari 0.3503, f1 0.5308
# epoch 11:acc 0.5871, nmi 0.4168, ari 0.3501, f1 0.5319
# epoch 12:acc 0.5949, nmi 0.4278, ari 0.3628, f1 0.5378
# ...
